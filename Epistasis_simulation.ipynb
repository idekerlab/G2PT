# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.stats.multitest import multipletests
import networkx as nx
from collections import defaultdict
import itertools
from scipy import stats as sps
import json
import os
from src.utils.analysis.epistasis_simulation import simulate_epistasis, build_hierarchical_ontology

# %% [markdown]
# # -- Step 1: Generating HIGH-POWER Synthetic Data ---"
#
# ## --- Part 1: Generating synthetic genotype and hierarchy ---

# %%
# hyperparamters

output_dir = "./epistasis_simulation_samples/"
seed = 42
n_samples = 10000
n_pairs = 50
h2_epistatic = 0.1
ontology_coherence = 0.5
n_additive = 100

# %% [markdown]
# ### 1. Running simulation with parameters

# %%
sim = simulate_epistasis(
    n_samples=n_samples,
    n_snps=500,
    seed=seed,
    n_additive=n_additive,
    h2_additive=0.5,
    n_pairs=n_pairs,
    h2_epistatic=h2_epistatic,
)

# %% [markdown]
# ### 2. Building hierarchical ontology..

# %%
snp_df, gene_df, system_df = build_hierarchical_ontology(
    sim,
    n_genes=250,
    n_systems=50,
    ontology_coherence=ontology_coherence,
    n_causal_systems=20,
    causal_system_enrichment=20.0,
    seed=seed
)
# Out:
# Pre-calculating system pair pools for epistasis placement...
#   - Found 50 same-system pairs.
#   - Found 649 related-system pairs.
#   - Found 576 distant-system pairs.
# Assigning 50 epistatic pairs with ontology_coherence = 0.5...
# Warning: 42 genes were not assigned any SNPs. Assigning them now to random SNPs.
# LD structure found. Assigning chromosomes, positions, and blocks based on LD.

# %% [markdown]
# ### 3. Creating random covariates and phenotypes, and save genotypes

# %%
# Create consistent sample IDs
iids = [f'sample_{i}' for i in range(sim['y'].shape[0])]

# Save genotypes with IID as index and SNP IDs as columns
genotypes_df = pd.DataFrame(sim['G'], columns=snp_df.index.values)
genotypes_df.index = iids
genotypes_df.index.name = 'IID'
genotypes_df.to_csv(f"{output_dir}/genotypes.tsv", sep='\t')

# Save phenotypes and covariates with the same IIDs
pheno_df = pd.DataFrame({'FID': iids, 'IID': iids, 'phenotype': sim['y']})
pheno_df.to_csv(f"{output_dir}/simulation.pheno", index=False, sep='\t')

cov_df = pd.DataFrame({
    'FID': iids,
    'IID': iids,
    'SEX': np.random.randint(2, size=sim['y'].shape[0]),
    'AGE': np.random.randint(40, 70, size=sim['y'].shape[0])
})
cov_df.to_csv(f"{output_dir}/simulation.cov", index=False, sep='\t')

# %% [markdown]
# ### Saving mappings

# %%
snp_df.to_csv(f"{output_dir}/snp2gene.tsv", index=True, sep='\t')

# Combine gene->system and system->supersystem for the model's expected format
gene_df = gene_df.rename(columns={'gene_id': 'child', 'system_id': 'parent'})
gene_df['interaction'] = 'gene'
system_df = system_df.rename(columns={'system_id': 'child', 'supersystem_id': 'parent'})
system_df['interaction'] = 'default'

ontology_df = pd.concat([
    gene_df[['parent', 'child', 'interaction']],
    system_df[['parent', 'child', 'interaction']]
])
ontology_df.to_csv(f"{output_dir}/ontology.tsv", index=False, sep='\t', header=False)

# Causal Info for Evaluation
causal_info = {
    'epistatic_pairs': [list(map(int, p)) for p in sim['pair_idx']],
    'additive_snps': list(map(int, sim['additive_idx']))
}
with open(f"{output_dir}/causal_info.json", 'w') as f:
    json.dump(causal_info, f, indent=2)

print("Synthetic data generation complete.")
# Out:
# Synthetic data generation complete.

# %% [markdown]
# ## --- Part 2: Statistical Sanity Check ---
#
# ### 1. Load Ground Truth and Data

# %%
def _maf_from_dosage(g):
    g = np.asarray(g, float)
    g = g[~np.isnan(g)]
    if g.size == 0: return np.nan
    p = np.clip(g.mean() / 2.0, 0.0, 1.0)
    return min(p, 1 - p)

def _generate_penetrance_table_from_df(df, snp_cols, phenocol):
    k = len(snp_cols)
    pen = {gt: [] for gt in itertools.product(range(3), repeat=k)}
    gmat = df[snp_cols].astype('float')
    y = df[phenocol].values
    for idx in range(len(df)):
        gt_tuple = tuple(int(gmat.iloc[idx, c]) if pd.notna(gmat.iloc[idx, c]) else -1 for c in range(k)) 
        if -1 in gt_tuple: continue
        pen[gt_tuple].append(y[idx])
    return pen

def _one_way_anova_from_ptable(pen_table):
    non_empty = [phens for phens in pen_table.values() if len(phens) > 0]
    if len(non_empty) < 2: return np.nan
    _, p = sps.f_oneway(*non_empty)
    return float(p)

# %%
causal_info_path = f"{output_dir}/causal_info.json"
with open(causal_info_path, 'r') as f:
    causal_info = json.load(f)
true_epistatic_pairs = [tuple(p) for p in causal_info['epistatic_pairs']]
true_additive_snps = causal_info.get('additive_snps', [])
true_epistatic_snps = [snp for pair in true_epistatic_pairs for snp in pair]

genotypes = pd.read_csv(f"{output_dir}/genotypes.tsv", sep='\t', index_col='IID')
genotypes.columns = genotypes.columns.astype(str)
cov_pheno = pd.read_csv(f"{output_dir}/simulation.cov", sep='\t')
pheno = pd.read_csv(f"{output_dir}/simulation.pheno", sep='\t')
cov_pheno = cov_pheno.merge(pheno, on=['FID', 'IID'])
cov_pheno = cov_pheno.set_index('IID')
df_full = pd.concat([genotypes, cov_pheno], axis=1)

# %% [markdown]
# ### 2. Comprehensive Additive Effect Check for ALL SNPs

# %%
all_snps = genotypes.columns.tolist()
results_list = []
for snp in all_snps:
    df_snp = df_full[['phenotype', 'SEX', 'AGE', snp]].dropna()
    X = sm.add_constant(df_snp[['SEX', 'AGE', snp]])
    y = df_snp['phenotype']
    model = sm.OLS(y, X).fit()
    results_list.append({
        'SNP_ID': snp,
        'Coefficient': model.params[snp],
        'P_Value': model.pvalues[snp],
        'MAF': _maf_from_dosage(df_snp[snp]),
        'Is_True_Additive': int(snp) in true_additive_snps,
        'Is_In_Epistatic_Pair': int(snp) in true_epistatic_snps
    })

# %%
results_df = pd.DataFrame(results_list).sort_values(by='P_Value').reset_index(drop=True)
pd.set_option('display.max_rows', len(results_df) + 10)
pd.set_option('display.width', 120)

# %%
results_df.head()
# Out:
#   SNP_ID  Coefficient       P_Value      MAF  Is_True_Additive  Is_In_Epistatic_Pair
# 0    237    -0.215986  9.857912e-52  0.40345              True                 False
# 1     28     0.300011  1.211301e-43  0.11990              True                 False
# 2    238    -0.392271  1.348198e-40  0.05975              True                 False
# 3     27     0.361018  9.330822e-39  0.06875              True                 False
# 4     74     0.349903  5.103859e-38  0.07180              True                 False

# %% [markdown]
# ### 3. Interaction check for true epistatic pairs

# %%
if not true_epistatic_pairs:
    print("No true epistatic pairs to evaluate.")
else:
    interaction_results = []
    for snp1, snp2 in true_epistatic_pairs:
        s1, s2 = str(snp1), str(snp2)
        
        # ANOVA test
        p_val_anova, mafs = np.nan, (np.nan, np.nan)
        if s1 in df_full.columns and s2 in df_full.columns:
            df_pair = df_full[[s1, s2, 'phenotype']].dropna()
            mafs = (_maf_from_dosage(df_pair[s1].values), _maf_from_dosage(df_pair[s2].values))
            pen_table = _generate_penetrance_table_from_df(df_pair, [s1, s2], 'phenotype')
            p_val_anova = _one_way_anova_from_ptable(pen_table)
        
        # Linear model interaction test
        p_val_linear = np.nan
        if s1 in df_full.columns and s2 in df_full.columns:
            df_linear = df_full[['phenotype', 'SEX', 'AGE', s1, s2]].dropna()
            df_linear['interaction'] = df_linear[s1] * df_linear[s2]
            X = sm.add_constant(df_linear[['SEX', 'AGE', s1, s2, 'interaction']])
            y = df_linear['phenotype']
            model = sm.OLS(y, X).fit()
            p_val_linear = model.pvalues['interaction']

        interaction_results.append({
            'snp1': snp1, 'snp2': snp2, 
            'p_value_anova': p_val_anova,
            'p_value_linear': p_val_linear,
            'maf1': mafs[0], 'maf2': mafs[1],
        })

    interaction_df = pd.DataFrame(interaction_results)
    
    # Calculate FDR for both methods
    pvals_anova = interaction_df['p_value_anova'].dropna().to_numpy(dtype=float)
    if len(pvals_anova) > 0:
        reject_anova, fdr_anova, _, _ = multipletests(pvals_anova, alpha=0.05, method='fdr_bh')
        interaction_df.loc[interaction_df['p_value_anova'].notna(), 'p_value_anova_fdr'] = fdr_anova
    else:
        reject_anova = np.array([])
        interaction_df['p_value_anova_fdr'] = np.nan

    pvals_linear = interaction_df['p_value_linear'].dropna().to_numpy(dtype=float)
    if len(pvals_linear) > 0:
        reject_linear, fdr_linear, _, _ = multipletests(pvals_linear, alpha=0.05, method='fdr_bh')
        interaction_df.loc[interaction_df['p_value_linear'].notna(), 'p_value_linear_fdr'] = fdr_linear
    else:
        reject_linear = np.array([])
        interaction_df['p_value_linear_fdr'] = np.nan

    interaction_df = interaction_df.sort_values(by='p_value_linear').reset_index(drop=True)

    print("\n--- Full Report for True Epistatic Pairs (Interaction Tests) ---")
    #print(interaction_df[['snp1', 'snp2', 'maf1', 'maf2', 'p_value_anova', 'p_value_anova_fdr', 'p_value_linear', 'p_value_linear_fdr']])
    print(f"\nSummary (ANOVA): Found {reject_anova.sum()} / {len(true_epistatic_pairs)} pairs to be significant (FDR < 0.05).")
    print(f"Summary (Linear Model): Found {reject_linear.sum()} / {len(true_epistatic_pairs)} pairs to be significant (FDR < 0.05).")
    print("-----------------------------------------------------------------")
# Out:
# --- Full Report for True Epistatic Pairs (Interaction Tests) ---
#
# Summary (ANOVA): Found 50 / 50 pairs to be significant (FDR < 0.05).
# Summary (Linear Model): Found 49 / 50 pairs to be significant (FDR < 0.05).
# -----------------------------------------------------------------

# %%
interaction_df.head()
# Out:
#    snp1  snp2  p_value_anova  p_value_linear     maf1     maf2  p_value_anova_fdr  p_value_linear_fdr
# 0   453   212   2.264570e-24    2.087147e-14  0.12580  0.14115       3.774283e-23        1.043573e-12
# 1   208   346   1.405397e-10    8.352445e-12  0.10765  0.47830       5.019276e-10        2.088111e-10
# 2    86   427   8.580013e-43    1.512099e-11  0.37425  0.42880       4.290007e-41        2.520165e-10
# 3   263   498   3.200972e-12    5.623156e-10  0.11410  0.20810       1.778318e-11        7.028946e-09
# 4   255    67   7.145301e-10    7.218037e-10  0.39205  0.18540       2.381767e-09        7.218037e-09

# %% [markdown]
# # Step 2: Training model with generated data

# %%
# !python train_snp2p_model.py \
    --train-tsv "epistasis_simulation_samples/genotypes.tsv" \
    --train-pheno "epistasis_simulation_samples/simulation.pheno" \
    --train-cov "epistasis_simulation_samples/simulation.cov" \
    --onto "epistasis_simulation_samples/ontology.tsv" \
    --snp2gene "epistasis_simulation_samples/snp2gene.tsv" \
    --out "epistasis_simulation_samples/output_model.txt" \
    --epochs 51 \
    --batch-size 64 \
    --lr 1e-4 \
    --qt "phenotype" \
    --jobs 4 \
    --cuda 0 \
    --sys2env --env2sys --sys2gene \
    --sys2pheno --gene2pheno \
    --val-step 50 \
    --use_hierarchical_transformer
# Out:
# Python __main__
# Start Process
# train_snp2p_model.py:161: UserWarning: You have chosen a specific GPU. This will completely disable data parallelism.
#   warnings.warn('You have chosen a specific GPU. This will completely '
# DDP setup done
# [0/1] running on nrnb-gpu-06 GPU 0, rank: 0, local_rank: 0
# Finish setup main worker 0
# Processing Ontology dataframe...
# Building system and gene indices dictionary..
# Creating masks..
# 102 Systems are queried
# 250 Genes are queried
# Building descendant dict
# Subtree types:  ['default']
# Processing Ontology dataframe...
# Building system and gene indices dictionary..
# Creating masks..
# 102 Systems are queried
# 250 Genes are queried
# Building descendant dict
# Subtree types:  ['default']
#    snp   gene  chr   pos  block
# 0    0  G0103    7   415      4
# 1    1  G0243    7  1267      4
# 2    2  G0061    7  1310      4
# 3    3  G0020    7  1970      4
# 4    4  G0145    7  2419      4
# The number of SNPs: 500
# Loading TSV data from epistasis_simulation_samples/genotypes.tsv
# Processing Covariates...
# Loading Covariate file at epistasis_simulation_samples/simulation.cov
# Processing Phenotypes
# Loading Phenotype file at epistasis_simulation_samples/simulation.pheno
# Phenotypes:  ['phenotype']
# Phenotype index:  {'phenotype': 0}
# Phenotype data type:  {'phenotype': 'qt'}
# Loading Genotype data at epistasis_simulation_samples/genotypes.tsv
# loading done
# genotype data shape:  (10000, 500)
# From TSV 500 variants with 10000 samples are queried
# Loading done...
# Summary of trainable parameters
# Model will use Sys2Env
# Model will use Env2Sys
# Model will use Sys2Gene
# Model is initialized with 102 systems and 250 gene mutations
# Cov effect:  pre
# Input format:  indices
# The number of geno2pheno:  2
# Using independent predictors: False
# Using a single shared predictor.
# Model is loaded at GPU(0)
# Summary of trainable parameters
# +----------------------------------------------------------------------+------------+-----------+
# |                               Modules                                | Parameters | Trainable |
# +----------------------------------------------------------------------+------------+-----------+
# |                          system_value_scale                          |    103     |    True   |
# |                           gene_value_scale                           |    251     |    True   |
# |                       system_embedding.weight                        |   26624    |    True   |
# |                        gene_embedding.weight                         |   64256    |    True   |
# |                     mut_update_norm_inner.weight                     |    256     |    True   |
# |                      mut_update_norm_inner.bias                      |    256     |    True   |
# |                     mut_update_norm_outer.weight                     |    256     |    True   |
# |                      mut_update_norm_outer.bias                      |    256     |    True   |
# |                   sys2env_update_norm_inner.weight                   |    256     |    True   |
# |                    sys2env_update_norm_inner.bias                    |    256     |    True   |
# |                   sys2env_update_norm_outer.weight                   |    256     |    True   |
# |                    sys2env_update_norm_outer.bias                    |    256     |    True   |
# |                   env2sys_update_norm_inner.weight                   |    256     |    True   |
# |                    env2sys_update_norm_inner.bias                    |    256     |    True   |
# |                   env2sys_update_norm_outer.weight                   |    256     |    True   |
# |                    env2sys_update_norm_outer.bias                    |    256     |    True   |
# |                  sys2gene_update_norm_inner.weight                   |    256     |    True   |
# |                   sys2gene_update_norm_inner.bias                    |    256     |    True   |
# |                  sys2gene_update_norm_outer.weight                   |    256     |    True   |
# |                   sys2gene_update_norm_outer.bias                    |    256     |    True   |
# |    sys2env.default.hierarchical_transformer_update.q_proj.weight     |   65536    |    True   |
# |    sys2env.default.hierarchical_transformer_update.k_proj.weight     |   65536    |    True   |
# |    sys2env.default.hierarchical_transformer_update.v_proj.weight     |   65536    |    True   |
# |    sys2env.default.hierarchical_transformer_update.o_proj.weight     |   65536    |    True   |
# |   sys2env.default.hierarchical_transformer_update.norm_ffn.weight    |    256     |    True   |
# |    sys2env.default.hierarchical_transformer_update.norm_ffn.bias     |    256     |    True   |
# |    sys2env.default.hierarchical_transformer_update.ffn.w12.weight    |   131072   |    True   |
# |   sys2env.default.hierarchical_transformer_update.ffn.proj.weight    |   65536    |    True   |
# |    env2sys.default.hierarchical_transformer_update.q_proj.weight     |   65536    |    True   |
# |    env2sys.default.hierarchical_transformer_update.k_proj.weight     |   65536    |    True   |
# |    env2sys.default.hierarchical_transformer_update.v_proj.weight     |   65536    |    True   |
# |    env2sys.default.hierarchical_transformer_update.o_proj.weight     |   65536    |    True   |
# |   env2sys.default.hierarchical_transformer_update.norm_ffn.weight    |    256     |    True   |
# |    env2sys.default.hierarchical_transformer_update.norm_ffn.bias     |    256     |    True   |
# |    env2sys.default.hierarchical_transformer_update.ffn.w12.weight    |   131072   |    True   |
# |   env2sys.default.hierarchical_transformer_update.ffn.proj.weight    |   65536    |    True   |
# |        sys2gene.hierarchical_transformer_update.q_proj.weight        |   65536    |    True   |
# |        sys2gene.hierarchical_transformer_update.k_proj.weight        |   65536    |    True   |
# |        sys2gene.hierarchical_transformer_update.v_proj.weight        |   65536    |    True   |
# |        sys2gene.hierarchical_transformer_update.o_proj.weight        |   65536    |    True   |
# |       sys2gene.hierarchical_transformer_update.norm_ffn.weight       |    256     |    True   |
# |        sys2gene.hierarchical_transformer_update.norm_ffn.bias        |    256     |    True   |
# |       sys2gene.hierarchical_transformer_update.ffn.w12.weight        |   131072   |    True   |
# |       sys2gene.hierarchical_transformer_update.ffn.proj.weight       |   65536    |    True   |
# |                           gene_norm.weight                           |    256     |    True   |
# |                            gene_norm.bias                            |    256     |    True   |
# |                           sys_norm.weight                            |    256     |    True   |
# |                            sys_norm.bias                             |    256     |    True   |
# |                          effect_norm.weight                          |    256     |    True   |
# |                           effect_norm.bias                           |    256     |    True   |
# |                         snp_embedding.weight                         |   384512   |    True   |
# |                         snp_batch_norm.gamma                         |    256     |    True   |
# |                         snp_batch_norm.beta                          |    256     |    True   |
# |                          gate_mlp.0.weight                           |   196608   |    True   |
# |                           gate_mlp.0.bias                            |    256     |    True   |
# |                          gate_mlp.2.weight                           |    768     |    True   |
# |                           gate_mlp.2.bias                            |     3      |    True   |
# |                           snp_norm.weight                            |    256     |    True   |
# |                            snp_norm.bias                             |    256     |    True   |
# |                  snp2gene_update_norm_inner.weight                   |    256     |    True   |
# |                   snp2gene_update_norm_inner.bias                    |    256     |    True   |
# |                  snp2gene_update_norm_outer.weight                   |    256     |    True   |
# |                   snp2gene_update_norm_outer.bias                    |    256     |    True   |
# |        snp2gene.hierarchical_transformer_update.q_proj.weight        |   65536    |    True   |
# |        snp2gene.hierarchical_transformer_update.k_proj.weight        |   65536    |    True   |
# |        snp2gene.hierarchical_transformer_update.v_proj.weight        |   65536    |    True   |
# |        snp2gene.hierarchical_transformer_update.o_proj.weight        |   65536    |    True   |
# |       snp2gene.hierarchical_transformer_update.norm_ffn.weight       |    256     |    True   |
# |        snp2gene.hierarchical_transformer_update.norm_ffn.bias        |    256     |    True   |
# |       snp2gene.hierarchical_transformer_update.ffn.w12.weight        |   131072   |    True   |
# |       snp2gene.hierarchical_transformer_update.ffn.proj.weight       |   65536    |    True   |
# |        gene2snp.hierarchical_transformer_update.q_proj.weight        |   65536    |    True   |
# |        gene2snp.hierarchical_transformer_update.k_proj.weight        |   65536    |    True   |
# |        gene2snp.hierarchical_transformer_update.v_proj.weight        |   65536    |    True   |
# |        gene2snp.hierarchical_transformer_update.o_proj.weight        |   65536    |    True   |
# |       gene2snp.hierarchical_transformer_update.norm_ffn.weight       |    256     |    True   |
# |        gene2snp.hierarchical_transformer_update.norm_ffn.bias        |    256     |    True   |
# |       gene2snp.hierarchical_transformer_update.ffn.w12.weight        |   131072   |    True   |
# |       gene2snp.hierarchical_transformer_update.ffn.proj.weight       |   65536    |    True   |
# |                  gene2sys_update_norm_inner.weight                   |    256     |    True   |
# |                   gene2sys_update_norm_inner.bias                    |    256     |    True   |
# |                  gene2sys_update_norm_outer.weight                   |    256     |    True   |
# |                   gene2sys_update_norm_outer.bias                    |    256     |    True   |
# |        gene2sys.hierarchical_transformer_update.q_proj.weight        |   65536    |    True   |
# |        gene2sys.hierarchical_transformer_update.k_proj.weight        |   65536    |    True   |
# |        gene2sys.hierarchical_transformer_update.v_proj.weight        |   65536    |    True   |
# |        gene2sys.hierarchical_transformer_update.o_proj.weight        |   65536    |    True   |
# |       gene2sys.hierarchical_transformer_update.norm_ffn.weight       |    256     |    True   |
# |        gene2sys.hierarchical_transformer_update.norm_ffn.bias        |    256     |    True   |
# |       gene2sys.hierarchical_transformer_update.ffn.w12.weight        |   131072   |    True   |
# |       gene2sys.hierarchical_transformer_update.ffn.proj.weight       |   65536    |    True   |
# |                     cov_update_norm_inner.weight                     |    256     |    True   |
# |                      cov_update_norm_inner.bias                      |    256     |    True   |
# |                     cov_update_norm_outer.weight                     |    256     |    True   |
# |                      cov_update_norm_outer.bias                      |    256     |    True   |
# |                       cov2gene.to_gamma.weight                       |    768     |    True   |
# |                        cov2gene.to_gamma.bias                        |    256     |    True   |
# |                       cov2gene.to_beta.weight                        |    768     |    True   |
# |                        cov2gene.to_beta.bias                         |    256     |    True   |
# |                       cov2sys.to_gamma.weight                        |    768     |    True   |
# |                        cov2sys.to_gamma.bias                         |    256     |    True   |
# |                        cov2sys.to_beta.weight                        |    768     |    True   |
# |                         cov2sys.to_beta.bias                         |    256     |    True   |
# |                       cov2snp.to_gamma.weight                        |    768     |    True   |
# |                        cov2snp.to_gamma.bias                         |    256     |    True   |
# |                        cov2snp.to_beta.weight                        |    768     |    True   |
# |                         cov2snp.to_beta.bias                         |    256     |    True   |
# |                      cov2pheno.to_gamma.weight                       |    768     |    True   |
# |                       cov2pheno.to_gamma.bias                        |    256     |    True   |
# |                       cov2pheno.to_beta.weight                       |    768     |    True   |
# |                        cov2pheno.to_beta.bias                        |    256     |    True   |
# |                      covariate_linear_1.weight                       |    768     |    True   |
# |                       covariate_linear_1.bias                        |    256     |    True   |
# |                      covariate_linear_2.weight                       |   65536    |    True   |
# |                       covariate_linear_2.bias                        |    256     |    True   |
# |                       covariate_norm_1.weight                        |    256     |    True   |
# |                        covariate_norm_1.bias                         |    256     |    True   |
# |                       covariate_norm_2.weight                        |    256     |    True   |
# |                        covariate_norm_2.bias                         |    256     |    True   |
# |                     phenotype_embeddings.weight                      |    256     |    True   |
# |                        gene2pheno_norm.weight                        |    256     |    True   |
# |                         gene2pheno_norm.bias                         |    256     |    True   |
# |                 gene2pheno_update_norm_inner.weight                  |    256     |    True   |
# |                  gene2pheno_update_norm_inner.bias                   |    256     |    True   |
# |                 gene2pheno_update_norm_outer.weight                  |    256     |    True   |
# |                  gene2pheno_update_norm_outer.bias                   |    256     |    True   |
# |  gene2pheno.attention.hierarchical_transformer_update.q_proj.weight  |   65536    |    True   |
# |  gene2pheno.attention.hierarchical_transformer_update.k_proj.weight  |   65536    |    True   |
# |  gene2pheno.attention.hierarchical_transformer_update.v_proj.weight  |   65536    |    True   |
# |  gene2pheno.attention.hierarchical_transformer_update.o_proj.weight  |   65536    |    True   |
# | gene2pheno.attention.hierarchical_transformer_update.norm_ffn.weight |    256     |    True   |
# |  gene2pheno.attention.hierarchical_transformer_update.norm_ffn.bias  |    256     |    True   |
# | gene2pheno.attention.hierarchical_transformer_update.ffn.w12.weight  |   131072   |    True   |
# | gene2pheno.attention.hierarchical_transformer_update.ffn.proj.weight |   65536    |    True   |
# |                  gene2pheno.feed_forward.w12.weight                  |   131072   |    True   |
# |                 gene2pheno.feed_forward.proj.weight                  |   65536    |    True   |
# |                        sys2pheno_norm.weight                         |    256     |    True   |
# |                         sys2pheno_norm.bias                          |    256     |    True   |
# |                  sys2pheno_update_norm_inner.weight                  |    256     |    True   |
# |                   sys2pheno_update_norm_inner.bias                   |    256     |    True   |
# |                  sys2pheno_update_norm_outer.weight                  |    256     |    True   |
# |                   sys2pheno_update_norm_outer.bias                   |    256     |    True   |
# |  sys2pheno.attention.hierarchical_transformer_update.q_proj.weight   |   65536    |    True   |
# |  sys2pheno.attention.hierarchical_transformer_update.k_proj.weight   |   65536    |    True   |
# |  sys2pheno.attention.hierarchical_transformer_update.v_proj.weight   |   65536    |    True   |
# |  sys2pheno.attention.hierarchical_transformer_update.o_proj.weight   |   65536    |    True   |
# | sys2pheno.attention.hierarchical_transformer_update.norm_ffn.weight  |    256     |    True   |
# |  sys2pheno.attention.hierarchical_transformer_update.norm_ffn.bias   |    256     |    True   |
# |  sys2pheno.attention.hierarchical_transformer_update.ffn.w12.weight  |   131072   |    True   |
# | sys2pheno.attention.hierarchical_transformer_update.ffn.proj.weight  |   65536    |    True   |
# |                  sys2pheno.feed_forward.w12.weight                   |   131072   |    True   |
# |                  sys2pheno.feed_forward.proj.weight                  |   65536    |    True   |
# |                          predictor.0.weight                          |   131072   |    True   |
# |                           predictor.0.bias                           |    256     |    True   |
# |                          predictor.2.weight                          |    256     |    True   |
# |                           predictor.2.bias                           |     1      |    True   |
# |                         snp_predictor.weight                         |   384512   |    True   |
# |                          snp_predictor.bias                          |    1502    |    True   |
# +----------------------------------------------------------------------+------------+-----------+
# Total Trainable Params: 5347396
# /cellar/users/i5lee/miniconda3/envs/G2PT_github/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Batch Train epoch:   1, Phenotype loss: 0.513, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 1: train_loss_epoch=0.5130
# Save to... epistasis_simulation_samples/output_model.txt.0
# MODEL_PATH:epistasis_simulation_samples/output_model.txt.0
# Batch Train epoch:   2, Phenotype loss: 0.506, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 2: train_loss_epoch=0.5063
# Batch Train epoch:   3, Phenotype loss: 0.500, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 3: train_loss_epoch=0.5003
# Batch Train epoch:   4, Phenotype loss: 0.506, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 4: train_loss_epoch=0.5064
# Batch Train epoch:   5, Phenotype loss: 0.499, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 5: train_loss_epoch=0.4989
# Batch Train epoch:   6, Phenotype loss: 0.493, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 6: train_loss_epoch=0.4928
# Batch Train epoch:   7, Phenotype loss: 0.491, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 7: train_loss_epoch=0.4908
# Batch Train epoch:   8, Phenotype loss: 0.490, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 8: train_loss_epoch=0.4897
# Batch Train epoch:   9, Phenotype loss: 0.485, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 9: train_loss_epoch=0.4853
# Batch Train epoch:  10, Phenotype loss: 0.482, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 10: train_loss_epoch=0.4818
# Batch Train epoch:  11, Phenotype loss: 0.479, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 11: train_loss_epoch=0.4795
# Batch Train epoch:  12, Phenotype loss: 0.481, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 12: train_loss_epoch=0.4806
# Batch Train epoch:  13, Phenotype loss: 0.478, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 13: train_loss_epoch=0.4776
# Batch Train epoch:  14, Phenotype loss: 0.478, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 14: train_loss_epoch=0.4782
# Batch Train epoch:  15, Phenotype loss: 0.475, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 15: train_loss_epoch=0.4749
# Batch Train epoch:  16, Phenotype loss: 0.474, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 16: train_loss_epoch=0.4737
# Batch Train epoch:  17, Phenotype loss: 0.471, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 17: train_loss_epoch=0.4710
# Batch Train epoch:  18, Phenotype loss: 0.465, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 18: train_loss_epoch=0.4648
# Batch Train epoch:  19, Phenotype loss: 0.453, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 19: train_loss_epoch=0.4530
# Batch Train epoch:  20, Phenotype loss: 0.437, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 20: train_loss_epoch=0.4368
# Batch Train epoch:  21, Phenotype loss: 0.401, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 21: train_loss_epoch=0.4006
# Batch Train epoch:  22, Phenotype loss: 0.387, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 22: train_loss_epoch=0.3873
# Batch Train epoch:  23, Phenotype loss: 0.365, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 23: train_loss_epoch=0.3648
# Batch Train epoch:  24, Phenotype loss: 0.351, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 24: train_loss_epoch=0.3505
# Batch Train epoch:  25, Phenotype loss: 0.339, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 25: train_loss_epoch=0.3386
# Batch Train epoch:  26, Phenotype loss: 0.333, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 26: train_loss_epoch=0.3328
# Batch Train epoch:  27, Phenotype loss: 0.322, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 27: train_loss_epoch=0.3216
# Batch Train epoch:  28, Phenotype loss: 0.321, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 28: train_loss_epoch=0.3210
# Batch Train epoch:  29, Phenotype loss: 0.317, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 29: train_loss_epoch=0.3172
# Batch Train epoch:  30, Phenotype loss: 0.305, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 30: train_loss_epoch=0.3045
# Batch Train epoch:  31, Phenotype loss: 0.305, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 31: train_loss_epoch=0.3047
# Batch Train epoch:  32, Phenotype loss: 0.300, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 32: train_loss_epoch=0.2996
# Batch Train epoch:  33, Phenotype loss: 0.300, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 33: train_loss_epoch=0.2999
# Batch Train epoch:  34, Phenotype loss: 0.297, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 34: train_loss_epoch=0.2973
# Batch Train epoch:  35, Phenotype loss: 0.294, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 35: train_loss_epoch=0.2945
# Batch Train epoch:  36, Phenotype loss: 0.295, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 36: train_loss_epoch=0.2951
# Batch Train epoch:  37, Phenotype loss: 0.293, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 37: train_loss_epoch=0.2928
# Batch Train epoch:  38, Phenotype loss: 0.291, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 38: train_loss_epoch=0.2908
# Batch Train epoch:  39, Phenotype loss: 0.289, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 39: train_loss_epoch=0.2893
# Batch Train epoch:  40, Phenotype loss: 0.288, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 40: train_loss_epoch=0.2878
# Batch Train epoch:  41, Phenotype loss: 0.280, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 41: train_loss_epoch=0.2795
# Batch Train epoch:  42, Phenotype loss: 0.281, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 42: train_loss_epoch=0.2807
# Batch Train epoch:  43, Phenotype loss: 0.282, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 43: train_loss_epoch=0.2818
# Batch Train epoch:  44, Phenotype loss: 0.281, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 44: train_loss_epoch=0.2811
# Batch Train epoch:  45, Phenotype loss: 0.277, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 45: train_loss_epoch=0.2767
# Batch Train epoch:  46, Phenotype loss: 0.273, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 46: train_loss_epoch=0.2731
# Batch Train epoch:  47, Phenotype loss: 0.278, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 47: train_loss_epoch=0.2780
# Batch Train epoch:  48, Phenotype loss: 0.274, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 48: train_loss_epoch=0.2744
# Batch Train epoch:  49, Phenotype loss: 0.270, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 49: train_loss_epoch=0.2696
# Batch Train epoch:  50, Phenotype loss: 0.274, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 50: train_loss_epoch=0.2743
# Batch Train epoch:  51, Phenotype loss: 0.268, SNPLoss: 0.000: 100%|█| 157/157 [
# Epoch 51: train_loss_epoch=0.2684
# Save to... epistasis_simulation_samples/output_model.txt.50
# MODEL_PATH:epistasis_simulation_samples/output_model.txt.50
# Save to... epistasis_simulation_samples/output_model.txt.best
# MODEL_PATH:epistasis_simulation_samples/output_model.txt.best

# %% [markdown]
# # Step 3: predict attention from trained model

# %%
# !python predict_attention.py \
    --model "epistasis_simulation_samples/output_model.txt.50" \
    --tsv "epistasis_simulation_samples/genotypes.tsv" \
    --pheno "epistasis_simulation_samples/simulation.pheno" \
    --cov "epistasis_simulation_samples/simulation.cov" \
    --onto "epistasis_simulation_samples/ontology.tsv" \
    --snp2gene "epistasis_simulation_samples/snp2gene.tsv" \
    --out "epistasis_simulation_samples/output_model.txt.50" \
    --batch-size 256 \
    --cuda 0
# Out:
# Processing Ontology dataframe...
# Building system and gene indices dictionary..
# Creating masks..
# 102 Systems are queried
# 250 Genes are queried
# Building descendant dict
# Subtree types:  ['default']
# Processing Ontology dataframe...
# Building system and gene indices dictionary..
# Creating masks..
# 102 Systems are queried
# 250 Genes are queried
# Building descendant dict
# Subtree types:  ['default']
#    snp   gene  chr   pos  block
# 0    0  G0103    7   415      4
# 1    1  G0243    7  1267      4
# 2    2  G0061    7  1310      4
# 3    3  G0020    7  1970      4
# 4    4  G0145    7  2419      4
# The number of SNPs: 500
# predict_attention.py:83: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   g2p_model_dict = torch.load(args.model, map_location='cuda:0')
# Namespace(batch_size=64, block_bias=False, bt=[], bt_inds=[], cov_effect='pre', cov_ids=[], cov_mean_dict={'AGE': 54.4924}, cov_std_dict={'AGE': 8.590408706934571}, cuda=0, dense_attention=False, distributed=False, dropout=0.2, env2sys=True, epochs=51, flip=False, focal_loss_alpha=0.25, focal_loss_gamma=2.0, gene2pheno=True, genotype_csv=None, hidden_dims=256, ind2pheno={0: 'phenotype'}, independent_predictors=False, input_format='indices', interaction_types=['default'], jobs=4, label_smoothing=0.0, local_rank=0, loss='default', lr=0.0001, mlm=False, model=None, n_cov=4, n_heads=4, ngpus_per_node=4, onto='epistasis_simulation_samples/ontology.tsv', out='epistasis_simulation_samples/output_model.txt', patience=10, pheno2ind={'phenotype': 0}, pheno2type={'phenotype': 'qt'}, pheno_ids=['phenotype'], prediction_head=1, qt=['phenotype'], qt_inds=[0], rank=0, regression=False, snp2gene='epistasis_simulation_samples/snp2gene.tsv', snp2pheno=False, start_epoch=0, subsample=None, sys2env=True, sys2gene=True, sys2pheno=True, target_phenotype=None, test_bfile=None, test_cov=None, test_pheno=None, train_bfile=None, train_cov='epistasis_simulation_samples/simulation.cov', train_pheno='epistasis_simulation_samples/simulation.pheno', train_tsv='epistasis_simulation_samples/genotypes.tsv', use_hierarchical_transformer=True, use_moe=False, val_bfile=None, val_cov=None, val_pheno=None, val_step=50, val_tsv=None, wd=0.001, world_size=1, z_weight=1.0)
# Processing Covariates...
# Loading Covariate file at epistasis_simulation_samples/simulation.cov
# Processing Phenotypes
# Loading Phenotype file at epistasis_simulation_samples/simulation.pheno
# Phenotypes:  ['phenotype']
# Phenotype index:  {'phenotype': 0}
# Phenotype data type:  {'phenotype': 'qt'}
# Loading Genotype data at epistasis_simulation_samples/genotypes.tsv
# loading done
# genotype data shape:  (10000, 500)
# From TSV 500 variants with 10000 samples are queried
# Model is initialized with 102 systems and 250 gene mutations
# Cov effect:  pre
# Input format:  indices
# The number of geno2pheno:  2
# Using independent predictors: False
# Using a single shared predictor.
# 100%|███████████████████████████████████████████| 40/40 [00:02<00:00, 16.34it/s]
# Saved attention for phenotype phenotype, head 0 to epistasis_simulation_samples/output_model.txt.50.phenotype.head_0.csv
# Saved system importance for phenotype phenotype, head 0 to epistasis_simulation_samples/output_model.txt.50.phenotype.head_0.sys_importance.csv
# Saved gene importance for phenotype phenotype, head 0 to epistasis_simulation_samples/output_model.txt.50.phenotype.head_0.gene_importance.csv
# Saved attention for phenotype phenotype, sum of heads to epistasis_simulation_samples/output_model.txt.50.phenotype.head_sum.csv
# Saved system importance for phenotype phenotype, sum of heads to epistasis_simulation_samples/output_model.txt.50.phenotype.head_sum.sys_importance.csv
# Saved gene importance for phenotype phenotype, sum of heads to epistasis_simulation_samples/output_model.txt.50.phenotype.head_sum.gene_importance.csv
# Saving to ...  epistasis_simulation_samples/output_model.txt.50

# %% [markdown]
# # Step 4: search epistasis and evaluate epistasis retrieval performance

# %%
from src.utils.analysis.epistasis_retrieval_evaluation import EvaluationConfig, EpistasisRetrievalEvaluator

# %%
config = EvaluationConfig(causal_info='epistasis_simulation_samples/causal_info.json',
                          attention_results='epistasis_simulation_samples/output_model.txt.50.phenotype.head_sum.csv',
                          system_importance='epistasis_simulation_samples/output_model.txt.50.phenotype.head_sum.sys_importance.csv',
                         tsv='epistasis_simulation_samples/genotypes.tsv',
                         pheno='epistasis_simulation_samples/simulation.pheno',
                         cov='epistasis_simulation_samples/simulation.cov',
                         onto='epistasis_simulation_samples/ontology.tsv',
                         snp2gene='epistasis_simulation_samples/snp2gene.tsv',
                         top_n_systems=5, # if None it will retrieve from all system
                          snp_threshold=50, # if None it will retrieve epistasis regardless of system size
                          num_workers=1,
                          executor_type='threads',
                          quantiles=[0.9],
                          output_prefix='epistasis_simulation_samples/simulation_output.50'
                         )

# %%
evaluator = EpistasisRetrievalEvaluator(config)

# %%
evaluator.evaluate()
# Out:
# --- [1/5] Loading inputs ---
# --- Loading causal info from epistasis_simulation_samples/causal_info.json ---
# --- Loaded 50 epistatic pairs and 100 additive SNPs ---
# --- Loading system importance from epistasis_simulation_samples/output_model.txt.50.phenotype.head_sum.sys_importance.csv ---
# --- System importance loaded. Shape: (102, 7) ---
# --- Identified top 5 systems ---
#
# --- Running Pre-flight Diagnostic Check ---
# Initializing a temporary parser to check data mapping...
# Processing Ontology dataframe...
# Building system and gene indices dictionary..
# Creating masks..
# 102 Systems are queried
# 250 Genes are queried
# Building descendant dict
# Subtree types:  ['default']
# Processing Ontology dataframe...
# Building system and gene indices dictionary..
# Creating masks..
# 102 Systems are queried
# 250 Genes are queried
# Building descendant dict
# Subtree types:  ['default']
#    snp   gene  chr   pos  block
# 0    0  G0103    7   415      4
# 1    1  G0243    7  1267      4
# 2    2  G0061    7  1310      4
# 3    3  G0020    7  1970      4
# 4    4  G0145    7  2419      4
# The number of SNPs: 500
# Parser initialized successfully.
# Found 200 of 200 causal SNPs in the parser's master list.
#
# Checking for causal SNPs within the top-ranked systems...
#   - SUCCESS: System 'L2_6' contains 19 causal SNP(s): [385, 398, 14, 405, 157, 421, 300, 431, 47, 188, 68, 231, 106, 109, 495, 498, 245, 247, 255]
#   - SUCCESS: System 'L1_8' contains 12 causal SNP(s): [448, 386, 69, 294, 486, 238, 272, 381, 403, 219, 444, 285]
#   - SUCCESS: System 'L6_0' contains 200 causal SNP(s): [6, 8, 10, 13, 14, 15, 19, 22, 24, 27, 28, 29, 30, 31, 32, 33, 34, 41, 47, 48, 50, 55, 57, 67, 68, 69, 70, 72, 73, 74, 79, 85, 86, 87, 90, 92, 95, 96, 98, 100, 102, 105, 106, 107, 109, 110, 115, 118, 119, 120, 122, 125, 126, 127, 128, 130, 132, 145, 147, 149, 150, 153, 157, 171, 173, 174, 178, 179, 180, 188, 192, 193, 194, 197, 201, 205, 207, 208, 209, 210, 212, 213, 216, 217, 218, 219, 225, 227, 229, 231, 236, 237, 238, 239, 241, 244, 245, 247, 249, 255, 257, 260, 262, 263, 265, 271, 272, 273, 275, 277, 281, 284, 285, 286, 288, 290, 291, 292, 294, 295, 299, 300, 305, 314, 317, 323, 327, 329, 330, 331, 338, 340, 342, 343, 345, 346, 353, 355, 360, 363, 364, 365, 368, 370, 372, 374, 376, 378, 381, 385, 386, 389, 390, 394, 395, 398, 399, 401, 403, 404, 405, 406, 408, 411, 414, 417, 421, 423, 425, 427, 429, 431, 437, 439, 441, 444, 448, 451, 453, 455, 456, 458, 459, 461, 462, 463, 464, 467, 474, 481, 484, 486, 489, 491, 492, 493, 494, 495, 497, 498]
#   - SUCCESS: System 'S025' contains 2 causal SNP(s): [106, 47]
#
# Checking root node(s): ['L6_0']
#   - Root 'L6_0' contains 200 causal SNP(s).
# --- End of Diagnostic Check ---
#
# --- [2/5] Building tasks ---
# --- [3/5] Processing systems ---
# --- Running in single-worker mode ---
# Processing Ontology dataframe...
# Building system and gene indices dictionary..
# Creating masks..
# 102 Systems are queried
# 250 Genes are queried
# Building descendant dict
# Subtree types:  ['default']
# Processing Ontology dataframe...
# Building system and gene indices dictionary..
# Creating masks..
# 102 Systems are queried
# 250 Genes are queried
# Building descendant dict
# Subtree types:  ['default']
#    snp   gene  chr   pos  block
# 0    0  G0103    7   415      4
# 1    1  G0243    7  1267      4
# 2    2  G0061    7  1310      4
# 3    3  G0020    7  1970      4
# 4    4  G0145    7  2419      4
# The number of SNPs: 500
# From TSV 500 variants with 10000 samples are queried
# --- Searching in System: S005 with quantile 0.9---
#   System SNPs (including hierarchy): 7
#   True Additive SNPs in System: 0 []
#   True Epistatic Pairs in System: 0 []
# System: S005, Sex: 2
# Running Chi-Square Test...
# 	Testing 7 SNPs on 1000 risky individuals
# 	From 7 SNPs, 5 SNPs pass Chi-Square test
# 	Generated 1 pairs from 2 non-significant SNPs for further testing.
# Filtering Close SNPs...
# 	From 10 significant pairs, 1 proximal pairs were removed, leaving 9.
# 	From 1 non-significant pairs, 0 proximal pairs were removed, leaving 1.
# Running Fisher's Exact Test on significant pairs...
# 	From 9 pairs, 1 passed Fisher test with FDR correction.
# Running Fisher's Exact Test on non-significant pairs...
# 	From 1 pairs, 0 passed Fisher test with FDR correction.
#   Called SNP Pairs (candidates for regression): 10
# --- Searching in System: L2_6 with quantile 0.9---
#   System SNPs (including hierarchy): 37
#   True Additive SNPs in System: 9 [385, 231, 300, 398, 14, 431, 47, 245, 157]
#   True Epistatic Pairs in System: 0 []
# System: L2_6, Sex: 2
# Running Chi-Square Test...
# 	Testing 37 SNPs on 1000 risky individuals
# 	From 37 SNPs, 10 SNPs pass Chi-Square test
# 	Generated 351 pairs from 27 non-significant SNPs for further testing.
# Filtering Close SNPs...
# 	From 45 significant pairs, 2 proximal pairs were removed, leaving 43.
# 	From 351 non-significant pairs, 3 proximal pairs were removed, leaving 348.
# Running Fisher's Exact Test on significant pairs...
# 	From 43 pairs, 0 passed Fisher test with FDR correction.
# Running Fisher's Exact Test on non-significant pairs...
# 	From 348 pairs, 0 passed Fisher test with FDR correction.
#   Called SNP Pairs (candidates for regression): 391
# --- Searching in System: L1_8 with quantile 0.9---
#   System SNPs (including hierarchy): 26
#   True Additive SNPs in System: 6 [448, 386, 294, 238, 403, 219]
#   True Epistatic Pairs in System: 0 []
# System: L1_8, Sex: 2
# Running Chi-Square Test...
# 	Testing 26 SNPs on 1000 risky individuals
# 	From 26 SNPs, 4 SNPs pass Chi-Square test
# 	Generated 231 pairs from 22 non-significant SNPs for further testing.
# Filtering Close SNPs...
# 	From 6 significant pairs, 0 proximal pairs were removed, leaving 6.
# 	From 231 non-significant pairs, 1 proximal pairs were removed, leaving 230.
# Running Fisher's Exact Test on significant pairs...
# 	From 6 pairs, 0 passed Fisher test with FDR correction.
# Running Fisher's Exact Test on non-significant pairs...
# 	From 230 pairs, 0 passed Fisher test with FDR correction.
#   Called SNP Pairs (candidates for regression): 236
# --- Searching in System: L6_0 with quantile 0.9---
# --- Skipping System: L6_0 with 500 SNPs (threshold 50) ---
# --- Searching in System: S025 with quantile 0.9---
#   System SNPs (including hierarchy): 5
#   True Additive SNPs in System: 1 [47]
#   True Epistatic Pairs in System: 0 []
# System: S025, Sex: 2
# Running Chi-Square Test...
# 	Testing 5 SNPs on 1000 risky individuals
# 	From 5 SNPs, 4 SNPs pass Chi-Square test
# 	Generated 0 pairs from 1 non-significant SNPs for further testing.
# Filtering Close SNPs...
# 	From 6 significant pairs, 0 proximal pairs were removed, leaving 6.
# 	From 0 non-significant pairs, 0 proximal pairs were removed, leaving 0.
# Running Fisher's Exact Test on significant pairs...
# 	From 6 pairs, 2 passed Fisher test with FDR correction.
#   Called SNP Pairs (candidates for regression): 6
# --- [4/5] Merging results from workers ---
# --- Preparing final ranked lists for evaluation ---
#
# --- Calculating Precision & Recall at FDR < 0.05 ---
# True Positives (TP): 0
# False Positives (FP): 2
# Precision: 0.0000
# Recall: 0.0000
#
# --- Final Performance Metrics ---
#               Metric     Value
# 0       AUC_Chi_Path  0.499804
# 1      AUPR_Chi_Path  0.000401
# 2    AUC_Fisher_Path  0.498144
# 3   AUPR_Fisher_Path  0.000401
# 4          AUC_Union  0.497959
# 5         AUPR_Union  0.000401
# 6   AUC_Intersection  0.499988
# 7  AUPR_Intersection  0.000401
# 8          Precision  0.000000
# 9             Recall  0.000000
# --- ROC and PR curves saved to epistasis_simulation_samples/simulation_output.50_union_curves.png ---
#
# Evaluation complete. Summary saved to epistasis_simulation_samples/simulation_output.50_summary_aupr.csv
# --- [5/5] Done ---
